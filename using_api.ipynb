# %%
import os
import dotenv

# %%
dotenv.load_dotenv()
# Out:
# True

# %%
print(os.getenv('EUROPEANA_API_KEY'))

# %%
import pyeuropeana.apis as apis
import pyeuropeana.utils as utils

# %%
# https://www.europeana.eu/en/search?page=1&view=grid&query=pl_wgs84_pos_lat%3A%28%2A%29

# %%
# FOR INFO ON THE API INPUT AND OUTPUT
# https://europeana.atlassian.net/wiki/spaces/EF/pages/2385739812/Search+API+Documentation#Getting-Started

# %%
# use this function to search our collections
alfred_metraux = apis.search(
    query = 'pl_wgs84_pos_lat:(*) AND Alfred Métraux'
    )

# %%
type(alfred_metraux)
# Out:
# dict

# %%
alfred_metraux.keys()
# Out:
# dict_keys(['apikey', 'success', 'requestNumber', 'itemsCount', 'totalResults', 'nextCursor', 'items', 'url', 'params'])

# %%
alfred_metraux
# Out:
# {'apikey': 'snetrourst',
#  'success': True,
#  'requestNumber': 999,
#  'itemsCount': 12,
#  'totalResults': 603,
#  'nextCursor': 'AoE/Ai85MTYwOS9TTVZLX1ZLTV9mb3RvZ3JhZmlfMTk2NzEzOA==',
#  'items': [{'completeness': 10,
#    'country': ['Sweden'],
#    'dataProvider': ['Museum of Ethnography'],
#    'dcDescription': ['Magasinet - En etnografisk skattkammare',
#     'Magasinet - K',
#     'America',
#     'Skinnkoffert. Rektangulär form med överfallande lock med kant. Flera vita skinnlager och mellan dem trälattor. Skinnlagren hopflätade med skinnremmar av vilka en del är svarta så att man på framsidan och lockkanten fått ett mönster. Ett handtag i vardera kortsidan. Erhållen av Rydén genom byte med dr. Alfred Métraux i Tucumán 1932, den senare hade i sin tur förvärvat den i Oruro i Bolivia.',
#     'K02',
#     'Bolivia',
#     '1959.10.0093',
#     '1959.10.0093',
#     'Magasinet - En etnografisk skattkammare',
#     'Magasinet - K',
#     'K02',
#     'Bolivia',
# ...

# %%
alfred_metraux_df = utils.search2df(alfred_metraux)

# %%
alfred_metraux["items"][0].keys()
# Out:
# dict_keys(['completeness', 'country', 'dataProvider', 'dcDescription', 'dcDescriptionLangAware', 'dcLanguage', 'dcLanguageLangAware', 'dcTitleLangAware', 'edmConcept', 'edmConceptLabel', 'edmConceptPrefLabelLangAware', 'edmDatasetName', 'edmIsShownAt', 'edmIsShownBy', 'edmPlaceAltLabel', 'edmPlaceAltLabelLangAware', 'edmPlaceLabel', 'edmPlaceLabelLangAware', 'edmPlaceLatitude', 'edmPlaceLongitude', 'edmPreview', 'europeanaCollectionName', 'europeanaCompleteness', 'guid', 'id', 'index', 'language', 'link', 'previewNoDistribute', 'provider', 'rights', 'score', 'timestamp', 'timestamp_created', 'timestamp_created_epoch', 'timestamp_update', 'timestamp_update_epoch', 'title', 'type', 'ugc'])

# %%
alfred_metraux["items"][0]["edmPlaceLatitude"]
# Out:
# ['-17.05687']

# %%
alfred_metraux["items"][0]["edmPlaceLongitude"]
# Out:
# ['-64.99123']

# %%
alfred_metraux_df.head()
# Out:
#                         europeana_id  \
# 0      /91619/SMVK_EM_objekt_2049392
# 1  /91609/SMVK_VKM_fotografi_2428024
# 2  /91609/SMVK_VKM_fotografi_2296254
# 3  /91609/SMVK_VKM_fotografi_2140800
# 4  /91609/SMVK_VKM_fotografi_1992417
#
#                                                  uri   type  \
# 0  http://data.europeana.eu/item/91619/SMVK_EM_ob...  IMAGE
# 1  http://data.europeana.eu/item/91609/SMVK_VKM_f...  IMAGE
# 2  http://data.europeana.eu/item/91609/SMVK_VKM_f...  IMAGE
# 3  http://data.europeana.eu/item/91609/SMVK_VKM_f...  IMAGE
# 4  http://data.europeana.eu/item/91609/SMVK_VKM_f...  IMAGE
#
#                                            image_url country  \
# 0  https://collections.smvk.se/carlotta-em/web/im...  Sweden
# 1  https://collections.smvk.se/carlotta-vkm/web/i...  Sweden
# 2  https://collections.smvk.se/carlotta-vkm/web/i...  Sweden
# 3  https://collections.smvk.se/carlotta-vkm/web/i...  Sweden
# 4  https://collections.smvk.se/carlotta-vkm/web/i...  Sweden
#
# ...

# %%
# # use this function to search our collections
# result = apis.search(
#     query = '*',
#     qf = '(skos_concept:"http://data.europeana.eu/concept/base/48" AND TYPE:IMAGE)',
#     reusability = 'open AND permission',
#     media = True,
#     thumbnail = True,
#     landingpage = True,
#     colourpalette = '#0000FF',
#     theme = 'photography',
#     sort = 'europeana_id',
#     profile = 'rich',
#     rows = 1000,
#     )

# # this gives you full response metadata along with cultural heritage object metadata
# # use this utility function to transform a subset of the cultural heritage object metadata
# # into a readable Pandas DataFrame
